# %%
for number in range(1,100):
    a = number % 3 == 0
    c = number & 2 == 0
    if a:
        print(number,"Bingo")
    elif c:
        print(number,"Uso")
    else:
        print(number,"0-0-0")
# Out:
# 1 Uso
# 2 0-0-0
# 3 Bingo
# 4 Uso
# 5 Uso
# 6 Bingo
# 7 0-0-0
# 8 Uso
# 9 Bingo
# 10 0-0-0
# 11 0-0-0
# 12 Bingo
# 13 Uso
# 14 0-0-0
# 15 Bingo
# 16 Uso
# 17 Uso
# 18 Bingo
# 19 0-0-0
# 20 Uso
# 21 Bingo
# 22 0-0-0
# 23 0-0-0
# 24 Bingo
# 25 Uso
# 26 0-0-0
# 27 Bingo
# 28 Uso
# 29 Uso
# 30 Bingo
# 31 0-0-0
# 32 Uso
# 33 Bingo
# 34 0-0-0
# 35 0-0-0
# 36 Bingo
# 37 Uso
# 38 0-0-0
# 39 Bingo
# 40 Uso
# 41 Uso
# 42 Bingo
# 43 0-0-0
# 44 Uso
# 45 Bingo
# 46 0-0-0
# 47 0-0-0
# 48 Bingo
# 49 Uso
# 50 0-0-0
# 51 Bingo
# 52 Uso
# 53 Uso
# 54 Bingo
# 55 0-0-0
# 56 Uso
# 57 Bingo
# 58 0-0-0
# 59 0-0-0
# 60 Bingo
# 61 Uso
# 62 0-0-0
# 63 Bingo
# 64 Uso
# 65 Uso
# 66 Bingo
# 67 0-0-0
# 68 Uso
# 69 Bingo
# 70 0-0-0
# 71 0-0-0
# 72 Bingo
# 73 Uso
# 74 0-0-0
# 75 Bingo
# 76 Uso
# 77 Uso
# 78 Bingo
# 79 0-0-0
# 80 Uso
# 81 Bingo
# 82 0-0-0
# 83 0-0-0
# 84 Bingo
# 85 Uso
# 86 0-0-0
# 87 Bingo
# 88 Uso
# 89 Uso
# 90 Bingo
# 91 0-0-0
# 92 Uso
# 93 Bingo
# 94 0-0-0
# 95 0-0-0
# 96 Bingo
# 97 Uso
# ...
